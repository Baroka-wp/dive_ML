# %% [markdown]
# ### [Problem] The day when chestnut buns cover the solar system

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def how_long_will_it_take_to_cover(any_volume):
    chestnut_buns_volume = 20 # initial chestnut buns volume cm3   
    chestnut_buns_volume_list = [] # to stock
    i = 0
    while True: 
        chestnut_buns_volume_list.append(chestnut_buns_volume)
        chestnut_buns_volume *= 2
        if any_volume <= chestnut_buns_volume:
            break
        i += 1
    print("it will take {} minutes".format((i*5),any_volume))
    
    return i*5,chestnut_buns_volume_list  # it take 5 minutes to double one time 
       

solar_system_volume = 24453*10**54  
lambda_volume = 1000

time_it_will_take,chestnut_buns_volume_list  = how_long_will_it_take_to_cover(lambda_housse)

print("\n")
print("-- GRAPHIC --")
plt.xlabel("time it will take")
plt.ylabel("volume to cover")
plt.plot(np.arange(0,time_it_will_take + 5 ,5),chestnut_buns_volume_list)
plt.show()
# Out:
# it will take 25 minutes
#
#
# -- GRAPHIC --
